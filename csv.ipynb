# %%
import pandas as pd 
import os
import json
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %%
# Ruta al archivo Parquet
ruta_parquet = '../Datasets/Yelp/user-001.parquet'

# Utiliza pandas para leer el archivo Parquet
df = pd.read_parquet(ruta_parquet)

# %%
reviews_ft = pd.read_csv('../Datasets/Yelp/reviews_ft.csv')

# %%
df
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...

# %%
reviews_ft
# Out:
#        Unnamed: 0.1  Unnamed: 0               review_id  \
# 0               476         476  zKZAppIn3yZVp7sTw-8ZLw
# 1               482         482  wR6Bl-Vywqd56UaogCcWNg
# 2               927         927  lqEa3ctJXMfAlA6RPiGrPA
# 3               988         988  zQ-WQotzv7NtuKxfMfpDKQ
# 4              1020        1020  QyvqHQzpNS1Zdiy88BIb3w
# ...             ...         ...                     ...
# 60216       6989669     6989669  W0G6HDShaInBoGJayleAbQ
# 60217       6989909     6989909  afEys2XQxx_IjfwoNcSqkA
# 60218       6990005     6990005  VkXr54yJMN4Qu4dRznAN8Q
# 60219       6990084     6990084  vyKPnyBiqlT8fzMOuD7PtQ
# 60220       6990179     6990179  Ar8boVUA9E_uJuHPYCyZFQ
#
#                       user_id             business_id  stars  useful  funny  \
# 0      au30JemWvCjjTp5vWdOLow  Gw7UW0E2BguzL9suQnwDeg      5       2      0
# 1      _mLEJyBITb35hF-av1Q09Q  rQW9iupvhk6ScPn2VPNLVQ      5       2      0
# ...

# %%
user_ft = df[df['user_id'].isin(reviews_ft['user_id'])]

# %%
business_ft = pd.read_csv('../Datasets/Yelp/business_FT.csv')

# %%
user_ft = pd.read_csv('../Datasets/Yelp/user_ft.csv')

# %%
user_ft.to_csv('../Datasets/Yelp/user_ft.csv', index=False)

# %%
reviews_ft = pd.read_csv('../Datasets/Yelp/reviews_ft.csv')

# %%
reviews_ft.to_csv('../Datasets/Yelp/reviews_ft.csv', index=False)

# %%
business_FT = pd.read_csv('../Datasets/Yelp/business_FT.csv')

# %%
business_FT.to_csv('../Datasets/Yelp/business_FT.csv')

# %%
tip = pd.read_json('../Datasets/Yelp/tip.json', lines=True, orient='records', encoding='utf-8')

# %%
tip[tip['business_id'].isin(business_ft['business_id'])]
# Out:
#                        user_id             business_id  \
# 62      BDOCu_rbF75vMK0stzxqkg  RiB0e4L-Gx3BJ5qlsa1ZIw
# 573     86Mv16c6S9NFMEWgj_0qsg  MK0OMY_u9unl8xSqjPLtMw
# 611     dOb9TFtmwlB7eLCLtlC-fQ  A1suinq7EcpyM06JIe7iOA
# 643     nl3bDwEL0bd3zya94OWH6A  MnxMt3CErrx4dXll4ADqLg
# 697     TiZBATmJUCYpyvVKbWdYSA  dfKF-oAUf3yjnD0WBYDyZQ
# ...                        ...                     ...
# 908505  b9kRJ-BW3X0TFFt06Za_Dw  JiBxL733qjm8WAddu-RzDQ
# 908555  SbuPacsdOmtLzPz6h0QF8Q  wqExA80UeX8ZNoFRhs4A4w
# 908761  3nVh-BD1arErB6_xdc50wQ  I_3LMZ_1m2mzR0oLIOePIg
# 908785  nV5mtqwWcirauUNsdKKJWQ  ckE45_JrmPgJ-DKYbV6IwA
# 908819  -czIXR8LOyeQBwctC1JmZQ  I_3LMZ_1m2mzR0oLIOePIg
#
#                                                      text                date  \
# 62      Great market! Beautiful location and easy park... 2017-10-01 14:42:06
# 573                                          Great place! 2014-03-17 19:30:57
# ...

# %%
tip[tip['user_id'].isin(user_ft['user_id'])]
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# 6       SMGAlRjyfuYu-c-22zIyOg  kH-0iXqkL7b8UXNpguBMKg
# 7       YVBB9g23nuVJ0u44zK0pSA  jtri188kuhe_AuEOJ51U_A
# ...                        ...                     ...
# 908652  QiTDKgcxVvrz7pDr_RZj7A  s7Y7ssmJEHh-vHkKX-q_Eg
# 908713  6RgZkRimG--Mx5B-DbzX7A  IpoUu-oHFFN8S9A1iUY2XA
# 908719  8TRbpFplrPDGeIwRUg0dIw  Q9NneDDl9zoPp4bCDK79Ug
# 908785  nV5mtqwWcirauUNsdKKJWQ  ckE45_JrmPgJ-DKYbV6IwA
# 908797  vUZz4qse2KQS9g8ux2ZIug  R_eXVjWKjlrf_HjJpmFmdg
#
#                                                      text                date  \
# 0                          Avengers time with the ladies. 2012-05-18 02:17:21
# 3                               Very decent fried chicken 2017-06-27 23:05:38
# ...

# %%
tip_ft = tip[(tip['business_id'].isin(business_ft['business_id']))&(tip['user_id'].isin(user_ft['user_id']))]

# %%
tip_ft.to_csv('../Datasets/Yelp/tip_ft.csv', index=False)

# %%
checkin_ft = pd.read_json('../Datasets/Yelp/checkin.json', lines=True, orient='records', encoding='utf-8')

# %%
checkin_ft = checkin_ft[checkin_ft['business_id'].isin(business_ft['business_id'])]

# %%
checkin_ft.to_csv('../Datasets/Yelp/checkin_ft.csv', index=False)
