# %%
import pandas as pd 
import os
import json
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import gzip

# %%
path_reviews = os.path.join('..','..','data','yelp','reviews.csv.gz')
reviews = pd.read_csv (path_reviews, compression='gzip')

# %% [markdown]
# # Extracción

# %%
users = pd.read_parquet('./Datasets/Yelp/user-001.parquet')

# %%
users
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...

# %% [markdown]
# ## Transformación

# %%
users = users[users['user_id'].isin(reviews['user_id'])]

# %% [markdown]
# ### División de datos para carga incremental

# %%
users['date_create_user'] = pd.to_datetime(users['yelping_since']).dt.year

users_2022 = users[users['date_create_user'] == 2022]
users = users[users['date_create_user'] < 2022]

# %% [markdown]
# ## Carga

# %%
user_path = os.path.join('..','..','data','yelp','users.csv.gz')
users.to_csv (user_path, compression='gzip', index=False)

user_path_2022 = os.path.join('..','..','data','yelp','users_2022.csv.gz')
users.to_csv (user_path_2022, compression='gzip', index=False)
